# %% [markdown]
# <a href="https://colab.research.google.com/github/mitozzz/My_First_Test_Repo/blob/master/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример Использования MARKDOWN
#
#
#
# 1.   Александров , Ходоев, Жданов
# 2.   ![1279988.jpg](data:image/jpeg;base64,...)
# 3.
# **1**|**2**|**3**
# :---:|:---:|:---:
# **a**|**b**|**c**
# 4. https://docs.google.com/spreadsheets/d/1-fHDOnuvCdszYsKZFy75tB3B55ov4YvPTKBCn14Vx3c/edit?usp=share_link
